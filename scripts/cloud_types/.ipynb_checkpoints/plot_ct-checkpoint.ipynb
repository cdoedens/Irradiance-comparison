# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from pathlib import Path

# %%
sb_path = Path('/g/data/er8/users/cd3022/Irradiance-comparisons/weather-features/sea_breeze')

him_files = [f for f in sb_path.glob('himawari*.nc')]
ds_him = xr.open_mfdataset(him_files, combine='nested', concat_dim='date')

bar_files = [f for f in sb_path.glob('barra-r2*.nc')]
ds_br2 = xr.open_mfdataset(bar_files, combine='nested', concat_dim='date')
# Out:
# /jobfs/160115766.gadi-pbs/ipykernel_2152365/3136311425.py:4: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ds_him = xr.open_mfdataset(him_files, combine='nested', concat_dim='date')
# /jobfs/160115766.gadi-pbs/ipykernel_2152365/3136311425.py:4: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
# ...

# %%
mean_him = ds_him.annual_mean_ghi.mean(dim='date')
mean_br2 = ds_br2.annual_mean_ghi.mean(dim='date')

mean_him = mean_him.interp(
    lat=mean_br2.lat,
    lon=mean_br2.lon,
    method='linear'
)

# %%
diff = mean_br2 - mean_him

# %%
diff
# Out:
# <xarray.DataArray 'annual_mean_ghi' (lat: 314, lon: 403)> Size: 1MB
# dask.array<sub, shape=(314, 403), dtype=float64, chunksize=(314, 403), chunktype=numpy.ndarray>
# Coordinates:
#   * lat                 (lat) float64 3kB -44.44 -44.33 -44.22 ... -10.12 -10.01
#   * lon                 (lon) float64 3kB 112.0 112.1 112.2 ... 156.1 156.2
#     crs                 int32 4B 0
#     height              float64 8B 1.5
#     level_height        float64 8B 5.0
#     model_level_number  int32 4B 1
#     sigma               float64 8B 0.9994

# %%
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})
ax.pcolormesh(
    diff.lon,
    diff.lat,
    diff,
    cmap='RdBu_r',
    vmin=-100, vmax=100
)
