# %%
import subprocess
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

script_to_run = 'preprocess_diffct'

# First full month of data (Aug '15) to latest (Jan '25)
for year in range(2016, 2025):
    for month in range(1,13):
        date = f'{year}-{month}'
        
        # Generate a unique file name based on iteration
        joboutdir = '/home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/'
        job_script_filename = joboutdir + f'{script_to_run}___' + date + '.qsub'
        
        # Open the file for writing
        with open(job_script_filename, "w") as f3:
            f3.write('#!/bin/bash \n')
            f3.write('#PBS -l walltime=1:00:00 \n')
            f3.write('#PBS -l mem=96GB \n')
            f3.write('#PBS -l ncpus=24 \n')
            f3.write('#PBS -l jobfs=10GB \n')
            f3.write('#PBS -l storage=gdata/xp65+gdata/er8+gdata/ob53+gdata/rt52+gdata/rv74+gdata/su28+scratch/er8 \n')
            f3.write('#PBS -l other=hyperthread \n')
            f3.write('#PBS -q normal \n')
            f3.write('#PBS -P er8 \n')
            f3.write(f'#PBS -o /home/548/cd3022/repos/Irradiance-comparisons/logs/preprocess_diffct_{date}.oe  \n')
            f3.write('#PBS -j oe \n')
            f3.write('cd /home/548/cd3022/repos/Irradiance-comparisons \n')
            f3.write('source ./env.sh \n')
            f3.write(f'python3 scripts/preprocess_diffct.py {date}\n')
    
    
        # Submit the generated script to the job scheduler (PBS) using qsub
        try:
            # Run the qsub command and submit the script
            subprocess.run(['qsub', job_script_filename], check=True)
            print(f"Job script {job_script_filename} submitted successfully.")
        except subprocess.CalledProcessError as e:
            print(f"Error submitting job script {job_script_filename}: {e}")
# Out:
# 150681865.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2016-1.qsub submitted successfully.
# 150681866.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2016-2.qsub submitted successfully.
# 150681867.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2016-3.qsub submitted successfully.
# 150681868.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2016-4.qsub submitted successfully.
# 150681869.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2016-5.qsub submitted successfully.
# 150681870.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2016-6.qsub submitted successfully.
# 150681871.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2016-7.qsub submitted successfully.
# 150681872.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2016-8.qsub submitted successfully.
# 150681873.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2016-9.qsub submitted successfully.
# 150681874.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2016-10.qsub submitted successfully.
# 150681875.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2016-11.qsub submitted successfully.
# 150681876.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2016-12.qsub submitted successfully.
# 150681877.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2017-1.qsub submitted successfully.
# 150681878.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2017-2.qsub submitted successfully.
# 150681879.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2017-3.qsub submitted successfully.
# 150681880.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2017-4.qsub submitted successfully.
# 150681881.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2017-5.qsub submitted successfully.
# 150681882.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2017-6.qsub submitted successfully.
# 150681883.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2017-7.qsub submitted successfully.
# 150681884.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2017-8.qsub submitted successfully.
# 150681885.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2017-9.qsub submitted successfully.
# 150681886.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2017-10.qsub submitted successfully.
# 150681887.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2017-11.qsub submitted successfully.
# 150681888.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2017-12.qsub submitted successfully.
# 150681889.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2018-1.qsub submitted successfully.
# 150681890.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2018-2.qsub submitted successfully.
# 150681891.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2018-3.qsub submitted successfully.
# 150681892.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2018-4.qsub submitted successfully.
# 150681893.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2018-5.qsub submitted successfully.
# 150681894.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2018-6.qsub submitted successfully.
# 150681895.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2018-7.qsub submitted successfully.
# 150681896.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2018-8.qsub submitted successfully.
# 150681897.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2018-9.qsub submitted successfully.
# 150681898.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2018-10.qsub submitted successfully.
# 150681899.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2018-11.qsub submitted successfully.
# 150681900.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2018-12.qsub submitted successfully.
# 150681901.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2019-1.qsub submitted successfully.
# 150681902.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2019-2.qsub submitted successfully.
# 150681903.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2019-3.qsub submitted successfully.
# 150681904.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2019-4.qsub submitted successfully.
# 150681905.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2019-5.qsub submitted successfully.
# 150681907.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2019-6.qsub submitted successfully.
# 150681908.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2019-7.qsub submitted successfully.
# 150681909.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2019-8.qsub submitted successfully.
# 150681910.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2019-9.qsub submitted successfully.
# 150681911.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2019-10.qsub submitted successfully.
# 150681912.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2019-11.qsub submitted successfully.
# 150681913.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2019-12.qsub submitted successfully.
# 150681914.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2020-1.qsub submitted successfully.
# 150681915.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2020-2.qsub submitted successfully.
# 150681916.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2020-3.qsub submitted successfully.
# 150681917.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2020-4.qsub submitted successfully.
# 150681918.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2020-5.qsub submitted successfully.
# 150681919.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2020-6.qsub submitted successfully.
# 150681920.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2020-7.qsub submitted successfully.
# 150681921.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2020-8.qsub submitted successfully.
# 150681922.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2020-9.qsub submitted successfully.
# 150681923.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2020-10.qsub submitted successfully.
# 150681924.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2020-11.qsub submitted successfully.
# 150681925.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2020-12.qsub submitted successfully.
# 150681926.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2021-1.qsub submitted successfully.
# 150681927.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2021-2.qsub submitted successfully.
# 150681928.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2021-3.qsub submitted successfully.
# 150681929.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2021-4.qsub submitted successfully.
# 150681930.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2021-5.qsub submitted successfully.
# 150681931.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2021-6.qsub submitted successfully.
# 150681932.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2021-7.qsub submitted successfully.
# 150681933.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2021-8.qsub submitted successfully.
# 150681934.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2021-9.qsub submitted successfully.
# 150681935.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2021-10.qsub submitted successfully.
# 150681936.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2021-11.qsub submitted successfully.
# 150681937.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2021-12.qsub submitted successfully.
# 150681938.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2022-1.qsub submitted successfully.
# 150681939.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2022-2.qsub submitted successfully.
# 150681940.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2022-3.qsub submitted successfully.
# 150681941.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2022-4.qsub submitted successfully.
# 150681942.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2022-5.qsub submitted successfully.
# 150681943.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2022-6.qsub submitted successfully.
# 150681944.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2022-7.qsub submitted successfully.
# 150681945.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2022-8.qsub submitted successfully.
# 150681946.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2022-9.qsub submitted successfully.
# 150681947.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2022-10.qsub submitted successfully.
# 150681948.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2022-11.qsub submitted successfully.
# 150681949.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2022-12.qsub submitted successfully.
# 150681950.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2023-1.qsub submitted successfully.
# 150681951.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2023-2.qsub submitted successfully.
# 150681952.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2023-3.qsub submitted successfully.
# 150681953.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2023-4.qsub submitted successfully.
# 150681954.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2023-5.qsub submitted successfully.
# 150681955.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2023-6.qsub submitted successfully.
# 150681956.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2023-7.qsub submitted successfully.
# 150681957.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2023-8.qsub submitted successfully.
# 150681958.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2023-9.qsub submitted successfully.
# 150681960.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2023-10.qsub submitted successfully.
# 150681961.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2023-11.qsub submitted successfully.
# 150681962.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2023-12.qsub submitted successfully.
# 150681963.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2024-1.qsub submitted successfully.
# 150681964.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2024-2.qsub submitted successfully.
# 150681965.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2024-3.qsub submitted successfully.
# 150681966.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2024-4.qsub submitted successfully.
# 150681967.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2024-5.qsub submitted successfully.
# 150681968.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2024-6.qsub submitted successfully.
# 150681969.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2024-7.qsub submitted successfully.
# 150681970.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2024-8.qsub submitted successfully.
# 150681971.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2024-9.qsub submitted successfully.
# 150681972.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2024-10.qsub submitted successfully.
# 150681973.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2024-11.qsub submitted successfully.
# 150681974.gadi-pbs
# Job script /home/548/cd3022/repos/Irradiance-comparisons/scripts/qsub_jobs/preprocess_diffct___2024-12.qsub submitted successfully.
